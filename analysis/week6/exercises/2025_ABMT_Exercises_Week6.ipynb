# %% [markdown]
# # Idea Behind This Exercisie
#
# The aim of this lab is to give you the tools to read and analyze MATSim results. The library used ([matsim-tools](https://github.com/matsim-vsp/matsim-python-tools)) also provides basic utilities to write MATSim files, which might be useful if you want to modify the input files for your project.
#
# Generating maps and analyses in python or another scripting languages has a few advantages compared to an interactive program, such as VIA:
# - it is much more configurable, and in particular makes it quite easy to make comparison between various runs or parts of the day
# - by being a script, it can easily be ran for multiple runs
#
# Where VIA shines is interactive analysis, and in particular visualization of movement, rather than aggregate quantities.
#
# Make sure that you install the required packages

# %% [markdown]
# #For this class we would need the matsim-tools package and contextily, so you need to pip install it if you haven't already. See below
#
# !pip install matsim-tools
#
# !pip install contextily

# %%
#!python.exe -m pip install

# %%
import matsim
import os
import contextily as ctx
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict

# %matplotlib inline

# %%
scenario_path = "..\\..\\..\\scenarios\\SiouxFalls"

# %% [markdown]
# # Network
#
# This section does not contain any exercise, but demonstrates how to read in and visualize the network

# %%
# This reads in the network in a structure that contains two tables, one for links and one for nodes.
network = matsim.read_network(os.path.join(scenario_path, "Siouxfalls_network_PT.xml"))

# this creates a geographic dataframe
network_geo = network.as_geo("epsg:26914")

## > How does the df (table) look like?
## > Can we see the different modes of transport in the data?
## > Can we see the coordinates of the links and nodes?
## > Can we plot this network?
## > What coordinate reference system is used here?
## > Can we add a map to the plot?
# Out:
# C:\Users\kaghog\AppData\Roaming\Python\Python310\site-packages\pyproj\crs\crs.py:143: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
network_geo.head()
# Out:
#        length  freespeed  capacity  permlanes oneway modes link_id from_node  \
# 0  450.064207       13.9    1964.0        2.0      1   car    10_1         4
# 1  450.064207       13.9    1964.0        2.0      1   car    10_2     4_101
# 2  450.064207       13.9    1964.0        2.0      1   car    10_3     4_102
# 3  450.064207       13.9    1964.0        2.0      1   car    10_4     4_103
# 4  450.064207       13.9    1964.0        2.0      1   car    10_5     4_104
#
#   to_node                                           geometry
# 0   4_101  LINESTRING (680827.028 4825897.167, 680841.192...
# 1   4_102  LINESTRING (680841.192 4825447.326, 680855.357...
# 2   4_103  LINESTRING (680855.357 4824997.485, 680869.522...
# 3   4_104  LINESTRING (680869.522 4824547.644, 680883.687...
# 4      11  LINESTRING (680883.687 4824097.802, 680897.851...

# %%
network_geo["modes"].unique()
# Out:
# array(['car', 'car,bus,pt'], dtype=object)

# %%
network_geo.crs
# Out:
# <Projected CRS: EPSG:26914>
# Name: NAD83 / UTM zone 14N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: North America - between 102°W and 96°W - onshore and offshore. Canada - Manitoba; Nunavut; Saskatchewan. United States (USA) - Iowa; Kansas; Minnesota; Nebraska; North Dakota; Oklahoma; South Dakota; Texas.
# - bounds: (-102.0, 25.83, -96.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 14N
# - method: Transverse Mercator
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
# plot the network
# Geopandas (the library providing geographic dataframes) provides methods to easily plot geographic data
# the network contains lots of links that represent the public transport connections. 
network_geo.plot(
    column="freespeed",
    figsize=(15,15),
    legend=True)
# Out:
# <Axes: >

# %%
# In the scenario we use, we can query for specific modes of transport.
# all road links have mode "car,pt"
network_geo.query('modes == "car,bus,pt"').plot(
    column="freespeed",
    figsize=(15,15),
    legend=True)
# Out:
# <Axes: >

# %%
ax = network_geo.query('modes == "car"').plot(
    column="freespeed",
    figsize=(15,15),
    legend=True)

# contextily provides an easy way to add a map background, useful to get context
ctx.add_basemap(ax=ax, crs=network_geo.crs)

# %% [markdown]
# # Population

# %%
# The plan reader gives an iterator over the plans in the file
# It actually just provides a way to iterate over the XML elements
plans = matsim.plan_reader(os.path.join(scenario_path, "Siouxfalls_population.xml.gz"))

# %%
plans
# Out:
# <generator object plan_reader at 0x000001A78ACC2F80>

# %%
# "next" provides one element of the iterator, which we use here to look at how the elements look like.
# The typical way to use an iterator is in a for loop (see below)
first_person, first_plan = next(plans)

# %%
# attrib provides the attributes of the tag, in the XML sense
first_person.attrib
# Out:
# {'id': '6510_1',
#  'sex': 'f',
#  'age': '51',
#  'car_avail': 'always',
#  'employed': 'yes'}

# %%
first_plan.attrib
# Out:
# {'selected': 'yes'}

# %%
# tags that contains elements, such as the plan, are also iterable. The elements can be named differently for example 'activities' instead of 'act'. This allows one to check.
list(first_plan)
# Out:
# [<Element 'act' at 0x000001A793C731F0>,
#  <Element 'leg' at 0x000001A793C70C70>,
#  <Element 'act' at 0x000001A793C703B0>,
#  <Element 'leg' at 0x000001A793C72250>,
#  <Element 'act' at 0x000001A7925C8040>]

# %%
# example of how to create a dataframe with activities
plans = matsim.plan_reader(os.path.join(scenario_path, "Siouxfalls_population.xml.gz"))

## create a list of records (dictionaries) for each activity
## each record should contain the person id, x and y coordinates, and type of activity
## we need to iterate over each person and their plan
## then create a dataframe from that list

records = []
for person, plan in plans:
    person_id = person.attrib['id']
    for plan_element in plan:
        if plan_element.tag == 'act':
            records.append({
                'id': person_id,
                'x': float(plan_element.attrib['x']),
                'y': float(plan_element.attrib['y']),
                'type': plan_element.attrib['type']
            })
activities = pd.DataFrame.from_records(records)
activities
# Out:
#              id            x             y       type
# 0        6510_1  686386.7981  4.824848e+06       home
# 1        6510_1  684264.4410  4.824161e+06       work
# 2        6510_1  686386.7981  4.824848e+06       home
# 3         768_2  685633.2670  4.823347e+06       home
# 4         768_2  685411.5824  4.824337e+06       work
# ...         ...          ...           ...        ...
# 252325  14905_2  683547.8639  4.823939e+06  secondary
# 252326  14905_2  682867.6221  4.824542e+06       home
# 252327  22813_2  684756.3648  4.823524e+06       home
# 252328  22813_2  684624.1636  4.824255e+06  secondary
# 252329  22813_2  684756.3648  4.823524e+06       home
#
# [252330 rows x 4 columns]

# %%
# Transform into a geographic dataframe and plot
activities_geo = gpd.GeoDataFrame(
    activities,
    geometry=gpd.points_from_xy(activities.x, activities.y),
    crs=network_geo.crs
)

# %%
activities_geo.head()
# Out:
#        id            x             y  type                        geometry
# 0  6510_1  686386.7981  4.824848e+06  home  POINT (686386.798 4824847.925)
# 1  6510_1  684264.4410  4.824161e+06  work  POINT (684264.441 4824161.496)
# 2  6510_1  686386.7981  4.824848e+06  home  POINT (686386.798 4824847.925)
# 3   768_2  685633.2670  4.823347e+06  home  POINT (685633.267 4823347.246)
# 4   768_2  685411.5824  4.824337e+06  work  POINT (685411.582 4824336.985)

# %%
ax=activities_geo.plot(column='type', figsize=(15,15), legend=True, alpha=0.2)
ctx.add_basemap(ax=ax, crs=activities_geo.crs)

# %% [markdown]
# ## Events
#
# The events are the trace of everything that happens in the simulated physical world, and can be used to produce all kind of analyses. It can be read in a way similar to the plans file.
#
# Events files are typically very big, and it is thus often a good idea to aggregate the information while reading the file. This is demonstrated here.

# %%
#Events in Siouxfall

events = matsim.event_reader(
    '..\\..\\..\\output_counter/output_events.xml.gz',
    # the reader offers a filter of event types for performance.
    # we will parse the file once and extract two tables: traffic counts over per half-day and mode of transport of departures per link
    types='left link,departure')

# %%
# defaultdict creates a value if not there. Here, it creates the default int, which is 0
link_counts = defaultdict(int)
departure_counts = defaultdict(int)

# function to identify the time period based on time of day
def time_period(time_s):
    if time_s < 12 * 3600:
        return "morning"
    return "afternoon"

# iterate through all the events. This takes a little while
for event in events:
    # as for the population, the objects reflect the structure of the XML file
    period = time_period(event["time"])
    link = event["link"]
    
    if event["type"] == "left link":
        link_counts[(link, period)] += 1
    if event["type"] == "departure":
        mode = event["legMode"]
        departure_counts[(link, period, mode)] += 1

# %%
len(link_counts)
# Out:
# 668

# %%
len(departure_counts)
# Out:
# 1013

# %%
link_counts
# Out:
# defaultdict(int,
#             {('44_1', 'morning'): 451,
#              ('39_1', 'morning'): 2509,
#              ('17_1', 'morning'): 1703,
#              ('55_1', 'morning'): 1796,
#              ('36_1', 'morning'): 1077,
#              ('61_1', 'morning'): 1176,
#              ('2_1', 'morning'): 130,
#              ('65_1', 'morning'): 1541,
#              ('4_1', 'morning'): 2766,
#              ('26_1', 'morning'): 312,
#              ('2_2', 'morning'): 125,
#              ('26_2', 'morning'): 254,
#              ('39_2', 'morning'): 1651,
#              ('36_2', 'morning'): 1077,
#              ('61_2', 'morning'): 1120,
#              ('65_2', 'morning'): 792,
#              ('55_2', 'morning'): 1514,
#              ('4_2', 'morning'): 2769,
#              ('44_2', 'morning'): 451,
#              ('17_2', 'morning'): 1617,
#              ('2_3', 'morning'): 105,
#              ('39_3', 'morning'): 1601,
#              ('36_3', 'morning'): 1077,
#              ('61_3', 'morning'): 1013,
#              ('67_1', 'morning'): 1062,
#              ('23_1', 'morning'): 188,
#              ('2_4', 'morning'): 100,
#              ('55_3', 'morning'): 1177,
#              ('4_3', 'morning'): 2770,
#              ('44_3', 'morning'): 451,
#              ('17_3', 'morning'): 1514,
#              ('2_5', 'morning'): 308,
#              ('39_4', 'morning'): 1587,
#              ('36_4', 'morning'): 1032,
#              ('61_4', 'morning'): 837,
#              ('67_2', 'morning'): 875,
#              ('23_2', 'morning'): 188,
#              ('47_1', 'morning'): 637,
#              ('2_6', 'morning'): 685,
#              ('22_1', 'morning'): 1163,
#              ('4_4', 'morning'): 2463,
#              ('44_4', 'morning'): 451,
#              ('76_1', 'morning'): 671,
#              ('58_1', 'morning'): 1489,
#              ('43_1', 'morning'): 988,
#              ('2_7', 'morning'): 891,
#              ('32_1', 'morning'): 1373,
#              ('23_3', 'morning'): 188,
#              ('47_2', 'morning'): 954,
#              ('22_2', 'morning'): 1060,
#              ('4_5', 'morning'): 1938,
#              ('44_5', 'morning'): 400,
#              ('2_8', 'morning'): 685,
#              ('76_2', 'morning'): 671,
#              ('58_2', 'morning'): 1290,
#              ('43_2', 'morning'): 821,
#              ('32_2', 'morning'): 1097,
#              ('12_1', 'morning'): 235,
#              ('2_9', 'morning'): 921,
#              ('47_3', 'morning'): 1218,
#              ('22_3', 'morning'): 938,
#              ('4_6', 'morning'): 1585,
#              ('42_1', 'morning'): 229,
#              ('71_1', 'morning'): 1164,
#              ('58_3', 'morning'): 1174,
#              ('43_3', 'morning'): 703,
#              ('12_2', 'morning'): 213,
#              ('32_3', 'morning'): 968,
#              ('47_4', 'morning'): 1060,
#              ('22_4', 'morning'): 842,
#              ('6_1', 'morning'): 1938,
#              ('42_2', 'morning'): 489,
#              ('4_7', 'morning'): 1723,
#              ('71_2', 'morning'): 1109,
#              ('52_1', 'morning'): 591,
#              ('43_4', 'morning'): 549,
#              ('12_3', 'morning'): 174,
#              ('32_4', 'morning'): 780,
#              ('20_1', 'morning'): 528,
#              ('50_1', 'morning'): 604,
#              ('52_2', 'morning'): 591,
#              ('73_1', 'morning'): 391,
#              ('6_2', 'morning'): 1750,
#              ('15_1', 'morning'): 714,
#              ('41_1', 'morning'): 908,
#              ('12_4', 'morning'): 148,
#              ('73_2', 'morning'): 417,
#              ('48_1', 'morning'): 950,
#              ('32_5', 'morning'): 547,
#              ('20_2', 'morning'): 528,
#              ('50_2', 'morning'): 715,
#              ('15_2', 'morning'): 599,
#              ('6_3', 'morning'): 1543,
#              ('41_2', 'morning'): 838,
#              ('12_5', 'morning'): 220,
#              ('74_1', 'morning'): 1497,
#              ('48_2', 'morning'): 806,
#              ('29_1', 'morning'): 1009,
#              ('15_3', 'morning'): 399,
#              ('9_1', 'morning'): 1307,
#              ('41_3', 'morning'): 874,
#              ('74_2', 'morning'): 1713,
#              ('14_1', 'morning'): 478,
#              ('48_3', 'morning'): 694,
#              ('29_2', 'morning'): 1061,
#              ('15_4', 'morning'): 283,
#              ('9_2', 'morning'): 1091,
#              ('41_4', 'morning'): 1162,
#              ('74_3', 'morning'): 1498,
#              ('48_4', 'morning'): 566,
#              ('14_2', 'morning'): 478,
#              ('29_3', 'morning'): 767,
#              ('15_5', 'morning'): 131,
#              ('9_3', 'morning'): 847,
#              ('29_4', 'morning'): 379,
#              ('27_1', 'morning'): 747,
#              ('14_3', 'morning'): 477,
#              ('13_1', 'morning'): 737,
#              ('11_1', 'morning'): 143,
#              ('49_1', 'morning'): 445,
#              ('9_4', 'morning'): 795,
#              ('27_2', 'morning'): 1251,
#              ('14_4', 'morning'): 477,
#              ('13_2', 'morning'): 767,
#              ('49_2', 'morning'): 381,
#              ('11_2', 'morning'): 143,
#              ('9_5', 'morning'): 711,
#              ('14_5', 'morning'): 477,
#              ('27_3', 'morning'): 1847,
#              ('53_1', 'morning'): 659,
#              ('13_3', 'morning'): 800,
#              ('11_3', 'morning'): 143,
#              ('14_6', 'morning'): 477,
#              ('25_1', 'morning'): 885,
#              ('27_4', 'morning'): 2299,
#              ('53_2', 'morning'): 491,
#              ('11_4', 'morning'): 143,
#              ('27_5', 'morning'): 2329,
#              ('53_3', 'morning'): 495,
#              ('11_5', 'morning'): 160,
#              ('33_1', 'morning'): 611,
#              ('59_1', 'morning'): 287,
#              ('8_1', 'morning'): 75,
#              ('33_2', 'morning'): 635,
#              ('59_2', 'morning'): 387,
#              ('25_2', 'morning'): 642,
#              ('33_3', 'morning'): 779,
#              ('59_3', 'morning'): 433,
#              ('8_2', 'morning'): 75,
#              ('28_1', 'morning'): 453,
#              ('8_3', 'morning'): 75,
#              ('28_2', 'morning'): 654,
#              ('5_1', 'morning'): 56,
#              ('5_2', 'morning'): 56,
#              ('28_3', 'morning'): 1017,
#              ('5_3', 'morning'): 56,
#              ('28_4', 'morning'): 1026,
#              ('5_4', 'morning'): 56,
#              ('5_5', 'morning'): 56,
#              ('46_1', 'morning'): 1528,
#              ('5_6', 'morning'): 56,
#              ('46_2', 'morning'): 1266,
#              ('5_7', 'morning'): 56,
#              ('69_1', 'morning'): 752,
#              ('5_8', 'morning'): 56,
#              ('45_3', 'morning'): 717,
#              ('45_4', 'morning'): 683,
#              ('51_1', 'morning'): 792,
#              ('51_2', 'morning'): 679,
#              ('50_3', 'morning'): 828,
#              ('51_3', 'morning'): 566,
#              ('51_4', 'morning'): 453,
#              ('37_7', 'morning'): 4253,
#              ('38_1', 'morning'): 3331,
#              ('38_2', 'morning'): 3141,
#              ('38_3', 'morning'): 2951,
#              ('38_4', 'morning'): 2761,
#              ('38_5', 'morning'): 2571,
#              ('35_1', 'morning'): 1708,
#              ('38_6', 'morning'): 2381,
#              ('35_2', 'morning'): 1707,
#              ('38_7', 'morning'): 2191,
#              ('30_1', 'morning'): 524,
#              ('35_3', 'morning'): 1707,
#              ('37_1', 'morning'): 1939,
#              ('35_4', 'morning'): 1630,
#              ('30_2', 'morning'): 800,
#              ('37_2', 'morning'): 2322,
#              ('35_5', 'morning'): 1430,
#              ('18_3', 'morning'): 1500,
#              ('30_3', 'morning'): 916,
#              ('37_3', 'morning'): 2550,
#              ('35_6', 'morning'): 1360,
#              ('18_4', 'morning'): 3414,
#              ('37_4', 'morning'): 2592,
#              ('35_7', 'morning'): 1182,
#              ('30_4', 'morning'): 794,
#              ('37_5', 'morning'): 1610,
#              ('16_1', 'morning'): 1291,
#              ('41_5', 'morning'): 1065,
#              ('16_2', 'morning'): 1178,
#              ('16_3', 'morning'): 977,
#              ('56_3', 'morning'): 1500,
#              ('56_4', 'morning'): 1479,
#              ('56_5', 'morning'): 1493,
#              ('70_1', 'morning'): 1038,
#              ('10_1', 'morning'): 1538,
#              ('56_6', 'morning'): 1464,
#              ('56_7', 'morning'): 1406,
#              ('70_2', 'morning'): 1154,
#              ('31_4', 'morning'): 1463,
#              ('10_2', 'morning'): 1538,
#              ('56_8', 'morning'): 1623,
#              ('70_4', 'morning'): 1188,
#              ('34_4', 'morning'): 987,
#              ('31_5', 'morning'): 1438,
#              ('10_3', 'morning'): 1538,
#              ('70_5', 'morning'): 1405,
#              ('10_4', 'morning'): 1538,
#              ('34_2', 'morning'): 1540,
#              ('72_1', 'morning'): 913,
#              ('31_2', 'morning'): 1955,
#              ('34_3', 'morning'): 1381,
#              ('20_3', 'morning'): 506,
#              ('16_4', 'morning'): 700,
#              ('72_2', 'morning'): 912,
#              ('31_3', 'morning'): 1549,
#              ('21_1', 'morning'): 1148,
#              ('72_3', 'morning'): 911,
#              ('40_1', 'morning'): 1182,
#              ('10_5', 'morning'): 1476,
#              ('72_4', 'morning'): 806,
#              ('40_2', 'morning'): 1015,
#              ('18_2', 'morning'): 1099,
#              ('70_3', 'morning'): 1309,
#              ('56_1', 'morning'): 881,
#              ('40_3', 'morning'): 1003,
#              ('72_5', 'morning'): 676,
#              ('31_1', 'morning'): 1922,
#              ('56_2', 'morning'): 1203,
#              ('54_1', 'morning'): 766,
#              ('40_4', 'morning'): 1003,
#              ('18_1', 'morning'): 803,
#              ('63_4', 'morning'): 888,
#              ('54_2', 'morning'): 1600,
#              ('54_3', 'morning'): 2190,
#              ('66_3', 'morning'): 1029,
#              ('66_4', 'morning'): 1456,
#              ('54_4', 'morning'): 2093,
#              ('45_2', 'morning'): 458,
#              ('66_5', 'morning'): 1651,
#              ('1_10', 'morning'): 804,
#              ('57_1', 'morning'): 157,
#              ('21_2', 'morning'): 921,
#              ('33_4', 'morning'): 677,
#              ('34_1', 'morning'): 1422,
#              ('57_2', 'morning'): 195,
#              ('21_4', 'morning'): 549,
#              ('57_3', 'morning'): 361,
#              ('21_5', 'morning'): 343,
#              ('57_4', 'morning'): 321,
#              ('63_2', 'morning'): 565,
#              ('74_4', 'morning'): 1370,
#              ('62_1', 'morning'): 535,
#              ('75_1', 'morning'): 1316,
#              ('62_2', 'morning'): 458,
#              ('63_1', 'morning'): 378,
#              ('63_3', 'morning'): 816,
#              ('59_4', 'morning'): 389,
#              ('75_2', 'morning'): 1186,
#              ('62_3', 'morning'): 723,
#              ('37_6', 'morning'): 1115,
#              ('75_3', 'morning'): 1056,
#              ('69_2', 'morning'): 737,
#              ('62_4', 'morning'): 772,
#              ('24_1', 'morning'): 181,
#              ('75_4', 'morning'): 926,
#              ('24_2', 'morning'): 181,
#              ('21_3', 'morning'): 684,
#              ('75_5', 'morning'): 796,
#              ('24_3', 'morning'): 181,
#              ('24_4', 'morning'): 181,
#              ('24_5', 'morning'): 181,
#              ('45_1', 'morning'): 378,
#              ('66_1', 'morning'): 331,
#              ('19_1', 'morning'): 269,
#              ('66_2', 'morning'): 323,
#              ('19_2', 'morning'): 269,
#              ('19_3', 'morning'): 269,
#              ('19_4', 'morning'): 269,
#              ('14_7', 'morning'): 1929,
#              ('68_1', 'morning'): 321,
#              ('68_2', 'morning'): 321,
#              ('68_3', 'morning'): 321,
#              ('68_4', 'morning'): 268,
#              ('60_1', 'morning'): 146,
#              ('60_2', 'morning'): 146,
#              ('60_3', 'morning'): 146,
#              ('60_4', 'morning'): 146,
#              ('60_5', 'morning'): 146,
#              ('64_1', 'morning'): 57,
#              ('60_6', 'morning'): 146,
#              ('64_2', 'morning'): 57,
#              ('60_7', 'morning'): 146,
#              ('60_8', 'morning'): 146,
#              ('64_3', 'morning'): 57,
#              ('64_4', 'morning'): 45,
#              ('7_1', 'morning'): 50,
#              ('7_2', 'morning'): 50,
#              ('7_3', 'morning'): 50,
#              ('7_4', 'morning'): 50,
#              ('7_5', 'morning'): 50,
#              ('7_6', 'morning'): 50,
#              ('7_7', 'morning'): 50,
#              ('5_9', 'morning'): 39,
#              ('3_1', 'morning'): 43,
#              ('3_2', 'morning'): 43,
#              ('3_3', 'morning'): 43,
#              ('3_4', 'morning'): 43,
#              ('3_5', 'morning'): 43,
#              ('3_6', 'morning'): 43,
#              ('3_7', 'morning'): 43,
#              ('3_8', 'morning'): 43,
#              ('3_9', 'morning'): 43,
#              ('3_10', 'morning'): 43,
#              ('1_1', 'morning'): 23,
#              ('1_2', 'morning'): 23,
#              ('1_3', 'morning'): 23,
#              ('1_4', 'morning'): 23,
#              ('1_5', 'morning'): 23,
#              ('1_6', 'morning'): 23,
#              ('1_7', 'morning'): 23,
#              ('1_8', 'morning'): 23,
#              ('1_9', 'morning'): 23,
#              ('44_1', 'afternoon'): 159,
#              ('2_1', 'afternoon'): 187,
#              ('26_1', 'afternoon'): 48,
#              ('15_1', 'afternoon'): 126,
#              ('1_1', 'afternoon'): 68,
#              ('36_1', 'afternoon'): 146,
#              ('4_1', 'afternoon'): 625,
#              ('70_4', 'afternoon'): 916,
#              ('4_7', 'afternoon'): 338,
#              ('35_2', 'afternoon'): 297,
#              ('72_3', 'afternoon'): 99,
#              ('66_2', 'afternoon'): 177,
#              ('71_1', 'afternoon'): 145,
#              ('14_3', 'afternoon'): 351,
#              ('2_2', 'afternoon'): 192,
#              ('21_1', 'afternoon'): 18,
#              ('1_2', 'afternoon'): 68,
#              ('16_4', 'afternoon'): 103,
#              ('47_4', 'afternoon'): 65,
#              ('40_3', 'afternoon'): 306,
#              ('16_3', 'afternoon'): 22,
#              ('47_3', 'afternoon'): 38,
#              ('35_3', 'afternoon'): 110,
#              ('4_6', 'afternoon'): 351,
#              ('17_3', 'afternoon'): 184,
#              ('72_2', 'afternoon'): 228,
#              ('72_1', 'afternoon'): 357,
#              ('42_2', 'afternoon'): 132,
#              ('17_2', 'afternoon'): 18,
#              ('44_2', 'afternoon'): 159,
#              ('36_2', 'afternoon'): 146,
#              ('16_2', 'afternoon'): 18,
#              ('50_1', 'afternoon'): 581,
#              ('2_3', 'afternoon'): 212,
#              ('16_1', 'afternoon'): 18,
#              ('4_2', 'afternoon'): 627,
#              ('70_5', 'afternoon'): 838,
#              ('1_3', 'afternoon'): 68,
#              ('66_3', 'afternoon'): 93,
#              ('14_4', 'afternoon'): 351,
#              ('19_1', 'afternoon'): 132,
#              ('2_5', 'afternoon'): 252,
#              ('2_4', 'afternoon'): 217,
#              ('57_3', 'afternoon'): 47,
#              ('73_1', 'afternoon'): 250,
#              ('1_4', 'afternoon'): 68,
#              ('36_3', 'afternoon'): 146,
#              ('44_3', 'afternoon'): 159,
#              ('50_2', 'afternoon'): 722,
#              ('4_3', 'afternoon'): 628,
#              ('71_2', 'afternoon'): 51,
#              ('2_6', 'afternoon'): 267,
#              ('54_2', 'afternoon'): 304,
#              ('34_4', 'afternoon'): 39,
#              ('14_5', 'afternoon'): 351,
#              ('1_5', 'afternoon'): 68,
#              ('19_2', 'afternoon'): 132,
#              ('54_3', 'afternoon'): 221,
#              ('44_4', 'afternoon'): 159,
#              ('1_6', 'afternoon'): 68,
#              ('40_1', 'afternoon'): 58,
#              ('4_4', 'afternoon'): 939,
#              ('19_3', 'afternoon'): 132,
#              ('42_1', 'afternoon'): 230,
#              ('14_6', 'afternoon'): 351,
#              ('14_7', 'afternoon'): 470,
#              ('1_7', 'afternoon'): 68,
#              ('2_7', 'afternoon'): 18,
#              ('20_3', 'afternoon'): 64,
#              ('18_3', 'afternoon'): 337,
#              ('40_2', 'afternoon'): 294,
#              ('14_1', 'afternoon'): 350,
#              ('19_4', 'afternoon'): 122,
#              ('1_8', 'afternoon'): 68,
#              ('4_5', 'afternoon'): 1158,
#              ('22_1', 'afternoon'): 18,
#              ('1_9', 'afternoon'): 68,
#              ('3_1', 'afternoon'): 101,
#              ('14_2', 'afternoon'): 350,
#              ('3_2', 'afternoon'): 101,
#              ('3_3', 'afternoon'): 101,
#              ('54_1', 'afternoon'): 406,
#              ('3_4', 'afternoon'): 101,
#              ('70_2', 'afternoon'): 660,
#              ('3_5', 'afternoon'): 101,
#              ('3_6', 'afternoon'): 101,
#              ('70_3', 'afternoon'): 668,
#              ('65_1', 'afternoon'): 113,
#              ('62_4', 'afternoon'): 269,
#              ('75_5', 'afternoon'): 267,
#              ('75_4', 'afternoon'): 267,
#              ('62_3', 'afternoon'): 149,
#              ('75_3', 'afternoon'): 267,
#              ('75_2', 'afternoon'): 180,
#              ('75_1', 'afternoon'): 50,
#              ('3_7', 'afternoon'): 101,
#              ('3_8', 'afternoon'): 101,
#              ('35_1', 'afternoon'): 359,
#              ('64_1', 'afternoon'): 45,
#              ('3_9', 'afternoon'): 101,
#              ('66_1', 'afternoon'): 226,
#              ('3_10', 'afternoon'): 101,
#              ('64_2', 'afternoon'): 45,
#              ('34_3', 'afternoon'): 18,
#              ('64_3', 'afternoon'): 45,
#              ('35_7', 'afternoon'): 19,
#              ('35_6', 'afternoon'): 19,
#              ('6_3', 'afternoon'): 67,
#              ('2_9', 'afternoon'): 23,
#              ('6_2', 'afternoon'): 45,
#              ('30_2', 'afternoon'): 46,
#              ('31_5', 'afternoon'): 36,
#              ('6_1', 'afternoon'): 29,
#              ('10_1', 'afternoon'): 103,
#              ('8_1', 'afternoon'): 27,
#              ('10_2', 'afternoon'): 103,
#              ('8_2', 'afternoon'): 27,
#              ('59_2', 'afternoon'): 86,
#              ('10_3', 'afternoon'): 103,
#              ('8_3', 'afternoon'): 27,
#              ('59_3', 'afternoon'): 28,
#              ('7_1', 'afternoon'): 5,
#              ('10_4', 'afternoon'): 103,
#              ('7_2', 'afternoon'): 5,
#              ('12_1', 'afternoon'): 70,
#              ('47_2', 'afternoon'): 160,
#              ('10_5', 'afternoon'): 183,
#              ('7_3', 'afternoon'): 5,
#              ('7_4', 'afternoon'): 5,
#              ('12_2', 'afternoon'): 91,
#              ('31_1', 'afternoon'): 167,
#              ('33_1', 'afternoon'): 88,
#              ('7_5', 'afternoon'): 5,
#              ('1_10', 'afternoon'): 124,
#              ('12_3', 'afternoon'): 130,
#              ('7_6', 'afternoon'): 5,
#              ('18_1', 'afternoon'): 220,
#              ('31_2', 'afternoon'): 165,
#              ('7_7', 'afternoon'): 5,
#              ('18_2', 'afternoon'): 254,
#              ('12_4', 'afternoon'): 132,
#              ('53_1', 'afternoon'): 183,
#              ('12_5', 'afternoon'): 48,
#              ('34_2', 'afternoon'): 18,
#              ('30_1', 'afternoon'): 135,
#              ('17_1', 'afternoon'): 18,
#              ('29_2', 'afternoon'): 344,
#              ('29_3', 'afternoon'): 216,
#              ('59_1', 'afternoon'): 48,
#              ('2_8', 'afternoon'): 18,
#              ('35_5', 'afternoon'): 18,
#              ('35_4', 'afternoon'): 18,
#              ('33_2', 'afternoon'): 18,
#              ('49_1', 'afternoon'): 104,
#              ('63_2', 'afternoon'): 115,
#              ('63_3', 'afternoon'): 18,
#              ('37_7', 'afternoon'): 31,
#              ('37_6', 'afternoon'): 18,
#              ('37_5', 'afternoon'): 18,
#              ('37_4', 'afternoon'): 19,
#              ('74_1', 'afternoon'): 18,
#              ('73_2', 'afternoon'): 41,
#              ('66_5', 'afternoon'): 36,
#              ('37_3', 'afternoon'): 18,
#              ('39_4', 'afternoon'): 26,
#              ('39_3', 'afternoon'): 18,
#              ('39_2', 'afternoon'): 18,
#              ('39_1', 'afternoon'): 20,
#              ('76_1', 'afternoon'): 11,
#              ('76_2', 'afternoon'): 11,
#              ('28_1', 'afternoon'): 50,
#              ('63_1', 'afternoon'): 73,
#              ('11_5', 'afternoon'): 23,
#              ('11_1', 'afternoon'): 20,
#              ('11_2', 'afternoon'): 20,
#              ('29_1', 'afternoon'): 363,
#              ('11_3', 'afternoon'): 20,
#              ('11_4', 'afternoon'): 20,
#              ('34_1', 'afternoon'): 18,
#              ('13_2', 'afternoon'): 18,
#              ('13_1', 'afternoon'): 18,
#              ('53_3', 'afternoon'): 25,
#              ('45_1', 'afternoon'): 18,
#              ('21_5', 'afternoon'): 20,
#              ('13_3', 'afternoon'): 20,
#              ('26_2', 'afternoon'): 18,
#              ('31_4', 'afternoon'): 18,
#              ('24_1', 'afternoon'): 2,
#              ('9_5', 'afternoon'): 20,
#              ('24_2', 'afternoon'): 2,
#              ('15_5', 'afternoon'): 64,
#              ('15_4', 'afternoon'): 140,
#              ('15_3', 'afternoon'): 140,
#              ('15_2', 'afternoon'): 157,
#              ('25_2', 'afternoon'): 61,
#              ('25_1', 'afternoon'): 28,
#              ('24_3', 'afternoon'): 2,
#              ('65_2', 'afternoon'): 94,
#              ('61_4', 'afternoon'): 23,
#              ('48_4', 'afternoon'): 181,
#              ('55_3', 'afternoon'): 182,
#              ('48_3', 'afternoon'): 181,
#              ('61_3', 'afternoon'): 23,
#              ('48_2', 'afternoon'): 181,
#              ('61_2', 'afternoon'): 23,
#              ('55_2', 'afternoon'): 284,
#              ('48_1', 'afternoon'): 252,
#              ('46_2', 'afternoon'): 74,
#              ('27_2', 'afternoon'): 18,
#              ('22_4', 'afternoon'): 221,
#              ('55_1', 'afternoon'): 435,
#              ('32_5', 'afternoon'): 38,
#              ('63_4', 'afternoon'): 62,
#              ('27_1', 'afternoon'): 18,
#              ('45_4', 'afternoon'): 31,
#              ('18_4', 'afternoon'): 793,
#              ('50_3', 'afternoon'): 626,
#              ('32_4', 'afternoon'): 38,
#              ('32_3', 'afternoon'): 100,
#              ('32_2', 'afternoon'): 100,
#              ('29_4', 'afternoon'): 181,
#              ('32_1', 'afternoon'): 183,
#              ('72_5', 'afternoon'): 74,
#              ('51_4', 'afternoon'): 87,
#              ('36_4', 'afternoon'): 133,
#              ('72_4', 'afternoon'): 74,
#              ('27_4', 'afternoon'): 82,
#              ('51_3', 'afternoon'): 87,
#              ('27_3', 'afternoon'): 18,
#              ('51_2', 'afternoon'): 87,
#              ('58_3', 'afternoon'): 66,
#              ('58_2', 'afternoon'): 66,
#              ('51_1', 'afternoon'): 87,
#              ('30_4', 'afternoon'): 69,
#              ('58_1', 'afternoon'): 66,
#              ('27_5', 'afternoon'): 189,
#              ('24_4', 'afternoon'): 2,
#              ('49_2', 'afternoon'): 76,
#              ('69_1', 'afternoon'): 42,
#              ('68_1', 'afternoon'): 35,
#              ('43_4', 'afternoon'): 169,
#              ('47_1', 'afternoon'): 291,
#              ('57_4', 'afternoon'): 78,
#              ('43_3', 'afternoon'): 236,
#              ('43_2', 'afternoon'): 236,
#              ('44_5', 'afternoon'): 210,
#              ('41_5', 'afternoon'): 105,
#              ('43_1', 'afternoon'): 302,
#              ('52_1', 'afternoon'): 87,
#              ('41_4', 'afternoon'): 53,
#              ('28_4', 'afternoon'): 100,
#              ('24_5', 'afternoon'): 2,
#              ('67_2', 'afternoon'): 68,
#              ('67_1', 'afternoon'): 118,
#              ('28_3', 'afternoon'): 39,
#              ('69_2', 'afternoon'): 42,
#              ('52_2', 'afternoon'): 87,
#              ('68_2', 'afternoon'): 35,
#              ('20_1', 'afternoon'): 128,
#              ('46_1', 'afternoon'): 41,
#              ('56_4', 'afternoon'): 18,
#              ('68_3', 'afternoon'): 35,
#              ('54_4', 'afternoon'): 200,
#              ('20_2', 'afternoon'): 128,
#              ('21_4', 'afternoon'): 18,
#              ('56_3', 'afternoon'): 18,
#              ('9_4', 'afternoon'): 18,
#              ('37_2', 'afternoon'): 18,
#              ('62_2', 'afternoon'): 18,
#              ('41_2', 'afternoon'): 18,
#              ('56_2', 'afternoon'): 18,
#              ('37_1', 'afternoon'): 18,
#              ('28_2', 'afternoon'): 18,
#              ('62_1', 'afternoon'): 18,
#              ('9_3', 'afternoon'): 18,
#              ('21_3', 'afternoon'): 18,
#              ('38_7', 'afternoon'): 18,
#              ('38_6', 'afternoon'): 18,
#              ('38_5', 'afternoon'): 18,
#              ('38_4', 'afternoon'): 18,
#              ('38_3', 'afternoon'): 18,
#              ('38_2', 'afternoon'): 18,
#              ('38_1', 'afternoon'): 18,
#              ('22_3', 'afternoon'): 76,
#              ('74_4', 'afternoon'): 28,
#              ('74_3', 'afternoon'): 28,
#              ('74_2', 'afternoon'): 28,
#              ('33_3', 'afternoon'): 24,
#              ('33_4', 'afternoon'): 33,
#              ('53_2', 'afternoon'): 18,
#              ('56_7', 'afternoon'): 18,
#              ('56_6', 'afternoon'): 18,
#              ('56_5', 'afternoon'): 18,
#              ('41_3', 'afternoon'): 18,
#              ('56_8', 'afternoon'): 39,
#              ('68_4', 'afternoon'): 30,
#              ('59_4', 'afternoon'): 20,
#              ('41_1', 'afternoon'): 18,
#              ('66_4', 'afternoon'): 18,
#              ('9_2', 'afternoon'): 18,
#              ('56_1', 'afternoon'): 18,
#              ('21_2', 'afternoon'): 18,
#              ('22_2', 'afternoon'): 20,
#              ('70_1', 'afternoon'): 495,
#              ('64_4', 'afternoon'): 56,
#              ('30_3', 'afternoon'): 18,
#              ('9_1', 'afternoon'): 18,
#              ('61_1', 'afternoon'): 18,
#              ('45_3', 'afternoon'): 18,
#              ('45_2', 'afternoon'): 18,
#              ('31_3', 'afternoon'): 17,
#              ('40_4', 'afternoon'): 223,
#              ('57_2', 'afternoon'): 13,
#              ('5_1', 'afternoon'): 22,
#              ('5_2', 'afternoon'): 22,
#              ('5_3', 'afternoon'): 22,
#              ('5_4', 'afternoon'): 22,
#              ('5_5', 'afternoon'): 22,
#              ('5_6', 'afternoon'): 22,
#              ('5_7', 'afternoon'): 22,
#              ('5_8', 'afternoon'): 22,
#              ('57_1', 'afternoon'): 9,
#              ('60_1', 'afternoon'): 15,
#              ('60_2', 'afternoon'): 15,
#              ('60_3', 'afternoon'): 15,
#              ('60_4', 'afternoon'): 15,
#              ('60_5', 'afternoon'): 15,
#              ('60_6', 'afternoon'): 15,
#              ('60_7', 'afternoon'): 14,
#              ('60_8', 'afternoon'): 14,
#              ('5_9', 'afternoon'): 21,
#              ('23_1', 'afternoon'): 2,
#              ('23_2', 'afternoon'): 2,
#              ('23_3', 'afternoon'): 2})

# %%
# transform collected data into a data frame
count_table = pd.DataFrame.from_records([
    {'link_id': link, 'period': period, 'link_count': link_count}
    for (link, period), link_count in link_counts.items()
])

#Load siouxfall network file
# This reads in the network in a structure that contains two tables, one for links and one for nodes.
network = matsim.read_network(os.path.join(scenario_path, "Siouxfalls_network_PT.xml"))

# this creates a geographic dataframe
network_geo = network.as_geo()
# merge with network data to be able to produce maps
count_table = network_geo.merge(count_table, on='link_id')
count_table.head()
# Out:
#        length  freespeed  capacity  permlanes oneway modes link_id from_node  \
# 0  450.064207       13.9    1964.0        2.0      1   car    10_1         4
# 1  450.064207       13.9    1964.0        2.0      1   car    10_1         4
# 2  450.064207       13.9    1964.0        2.0      1   car    10_2     4_101
# 3  450.064207       13.9    1964.0        2.0      1   car    10_2     4_101
# 4  450.064207       13.9    1964.0        2.0      1   car    10_3     4_102
#
#   to_node                                           geometry     period  \
# 0   4_101  LINESTRING (680827.028 4825897.167, 680841.192...    morning
# 1   4_101  LINESTRING (680827.028 4825897.167, 680841.192...  afternoon
# 2   4_102  LINESTRING (680841.192 4825447.326, 680855.357...    morning
# 3   4_102  LINESTRING (680841.192 4825447.326, 680855.357...  afternoon
# 4   4_103  LINESTRING (680855.357 4824997.485, 680869.522...    morning
#
#    link_count
# 0        1538
# 1         103
# 2        1538
# 3         103
# 4        1538

# %%
# plot counts for the morning period
ax=count_table.query("period == 'morning'").plot(column="link_count", figsize=(15,15), legend=True, cmap="Reds")
#ctx.add_basemap(ax, crs=activities_geo.crs)

# %%
# plot counts for the morning period
ax=count_table.query("period == 'morning'").plot(column="link_count", figsize=(15,15), legend=True, cmap="Reds")
ctx.add_basemap(ax, crs=activities_geo.crs)

# %% [markdown]
# ## Exercise: plot difference in traffic counts between morning and afternoon period
#
# Use the data collected from the events to plot a map of the difference of traffic in the two time periods.
# You are free to choose the method you prefer, but here are two suggestions:
# - use the "pivot" function (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.pivot.html#pandas.DataFrame.pivot)
# - split the count table in two tables, one per period, and re-merge them based on the link id. This would emulate how you would do it to compare separate runs, compared to values from the same run
